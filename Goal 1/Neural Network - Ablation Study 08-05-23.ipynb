# %%
import pandas as pd

# %%
games = pd.read_csv("nba_games.csv", index_col=0)

# %%
games.head()
# Out:
#     mp  mp.1  fg  fga    fg%  3p  3pa    3p%  ft  fta  ...  tov%_max_opp  \
# 0  240   240  39   81  0.481   6   20  0.300  14   18  ...          22.8
# 1  240   240  36  100  0.360   7   31  0.226  16   19  ...          50.0
# 2  240   240  37   85  0.435   8   19  0.421  17   23  ...          20.0
# 3  240   240  41   89  0.461   8   21  0.381  17   19  ...          28.6
# 4  240   240  27   86  0.314   6   26  0.231  15   20  ...          16.8
#
#    usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  home_opp  \
# 0          29.0           178           111       DAL         95         1
# 1          32.6           152           111       ATL         98         0
# 2          30.9           148           116       SAS        107         1
# 3          30.9           138           118       MIN         99         0
# 4          30.9           157            90       MEM         92         1
#
#    season        date    won
# 0    2016  09/12/2015   True
# 1    2016  09/12/2015  False
# 2    2018  18/10/2017  False
# 3    2018  18/10/2017   True
# 4    2021  30/04/2021  False
#
# [5 rows x 150 columns]

# %%
games.shape
# Out:
# (17772, 150)

# %%
games["team"].value_counts()
# Out:
# GSW    655
# BOS    653
# TOR    635
# MIL    628
# MIA    617
# CLE    610
# HOU    610
# LAC    607
# PHI    605
# UTA    605
# DEN    603
# POR    603
# OKC    595
# DAL    593
# SAS    593
# ATL    590
# PHO    590
# MEM    585
# IND    583
# LAL    581
# BRK    580
# WAS    580
# NOP    571
# ORL    565
# CHI    558
# MIN    558
# CHO    556
# DET    556
# SAC    554
# NYK    553
# Name: team, dtype: int64

# %%
games[games["team"] == "GSW"].sort_values("date")
# Out:
#         mp  mp.1  fg  fga    fg%  3p  3pa    3p%  ft  fta  ...  tov%_max_opp  \
# 15567  240   240  31   79  0.392   7   35  0.200  29   33  ...          50.0
# 16686  240   240  46   86  0.535  17   32  0.531  14   21  ...          17.6
# 1633   240   240  47   96  0.490  21   48  0.438  11   14  ...          29.4
# 1196   240   240  48   90  0.533  18   35  0.514  17   19  ...          27.4
# 13810  240   240  43   96  0.448  20   46  0.435  18   18  ...          23.1
# ...    ...   ...  ..  ...    ...  ..  ...    ...  ..  ...  ...           ...
# 2358   240   240  46   84  0.548  17   30  0.567  25   35  ...          33.3
# 12751  240   240  47   89  0.528  16   32  0.500  21   30  ...          31.6
# 10092  240   240  43   84  0.512  11   23  0.478  17   27  ...          20.5
# 8348   240   240  46   84  0.548  14   28  0.500  26   32  ...          50.0
# 14560  265   265  44   96  0.458  12   27  0.444  13   18  ...          50.0
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 15567          29.0           250           102       POR        123
# 16686          29.2           163           127       UTA        116
# 1633           30.8           231           131       CHO        111
# 1196           28.7           139           139       CLE        112
# 13810          34.6           230           138       SAS        120
# ...             ...           ...           ...       ...        ...
# 2358           36.1           218           131       NOP        120
# 12751          26.8           149           132       NOP        121
# 10092          34.3           157           124       HOU        110
# 8348           44.5           137           134       PHO        109
# 14560          25.9           175           120       SAS        117
#
#        home_opp  season        date    won
# 15567         0    2021  01/01/2021  False
# 16686         1    2022  01/01/2022   True
# 1633          0    2017  01/02/2017   True
# 1196          1    2020  01/02/2020   True
# 13810         1    2022  01/02/2022   True
# ...         ...     ...         ...    ...
# 2358          1    2016  31/10/2015   True
# 12751         0    2019  31/10/2018   True
# 10092         1    2016  31/12/2015   True
# 8348          1    2019  31/12/2018   True
# 14560         1    2020  31/12/2019  False
#
# [655 rows x 150 columns]

# %% [markdown]
# Counts how many games are in each season

# %%
games["season"].value_counts()
# Out:
# 2022    2646
# 2016    2632
# 2018    2624
# 2019    2624
# 2017    2618
# 2021    2342
# 2020    2286
# Name: season, dtype: int64

# %%
games.dtypes
# Out:
# mp             int64
# mp.1           int64
# fg             int64
# fga            int64
# fg%          float64
#               ...
# total_opp      int64
# home_opp       int64
# season         int64
# date          object
# won             bool
# Length: 150, dtype: object

# %% [markdown]
# Deleting column that is not needed

# %%
del games["mp.1"]

# %% [markdown]
# Converting existing column to a date time then overiding the existing column with the date time.

# %%
games["date"] = pd.to_datetime(games["date"], format="%d/%m/%Y")

# %%
games
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  tov%_max_opp  \
# 0      240  39   81  0.481   6   20  0.300  14   18  0.778  ...          22.8
# 1      240  36  100  0.360   7   31  0.226  16   19  0.842  ...          50.0
# 2      240  37   85  0.435   8   19  0.421  17   23  0.739  ...          20.0
# 3      240  41   89  0.461   8   21  0.381  17   19  0.895  ...          28.6
# 4      240  27   86  0.314   6   26  0.231  15   20  0.750  ...          16.8
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...           ...
# 17767  240  35   81  0.432  11   26  0.423  27   36  0.750  ...          34.2
# 17768  240  37   74  0.500  13   25  0.520  26   37  0.703  ...          25.0
# 17769  240  42   89  0.472  14   33  0.424  10   20  0.500  ...          25.6
# 17770  240  41   85  0.482   9   26  0.346  26   30  0.867  ...          27.7
# 17771  240  33   85  0.388  12   44  0.273  28   34  0.824  ...          51.5
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              29.0           178           111       DAL         95
# 1              32.6           152           111       ATL         98
# 2              30.9           148           116       SAS        107
# 3              30.9           138           118       MIN         99
# 4              30.9           157            90       MEM         92
# ...             ...           ...           ...       ...        ...
# 17767          33.7           160           118       OKC         92
# 17768          30.0           139           129       ORL        108
# 17769          29.9           175           126       LAC        113
# 17770          27.1           150           126       MIA        106
# 17771          36.2           141           114       BOS        117
#
#        home_opp  season       date    won
# 0             1    2016 2015-12-09   True
# 1             0    2016 2015-12-09  False
# 2             1    2018 2017-10-18  False
# 3             0    2018 2017-10-18   True
# 4             1    2021 2021-04-30  False
# ...         ...     ...        ...    ...
# 17767         0    2019 2018-10-19   True
# 17768         1    2017 2016-12-14   True
# 17769         0    2017 2016-12-14  False
# 17770         1    2020 2020-09-19   True
# 17771         0    2020 2020-09-19  False
#
# [17772 rows x 149 columns]

# %%
games.dtypes
# Out:
# mp                    int64
# fg                    int64
# fga                   int64
# fg%                 float64
# 3p                    int64
#                   ...
# total_opp             int64
# home_opp              int64
# season                int64
# date         datetime64[ns]
# won                    bool
# Length: 149, dtype: object

# %% [markdown]
# Creating predictors for machine learning
# home says wheteher the team played at a home game or an away game

# %% [markdown]
# concatenates the home category in the table

# %%
games ["venue_code"] = games["home"].astype("category").cat.codes

# %% [markdown]
# This creates the code for each opponent

# %%
games ["opp_code"] = games["team_opp"].astype("category").cat.codes

# %%
games ["day_code"] = games ["date"].dt.dayofweek

# %%
games
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  drtg_max_opp  \
# 0      240  39   81  0.481   6   20  0.300  14   18  0.778  ...           111
# 1      240  36  100  0.360   7   31  0.226  16   19  0.842  ...           111
# 2      240  37   85  0.435   8   19  0.421  17   23  0.739  ...           116
# 3      240  41   89  0.461   8   21  0.381  17   19  0.895  ...           118
# 4      240  27   86  0.314   6   26  0.231  15   20  0.750  ...            90
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...           ...
# 17767  240  35   81  0.432  11   26  0.423  27   36  0.750  ...           118
# 17768  240  37   74  0.500  13   25  0.520  26   37  0.703  ...           129
# 17769  240  42   89  0.472  14   33  0.424  10   20  0.500  ...           126
# 17770  240  41   85  0.482   9   26  0.346  26   30  0.867  ...           126
# 17771  240  33   85  0.388  12   44  0.273  28   34  0.824  ...           114
#
#        team_opp  total_opp  home_opp  season       date    won  venue_code  \
# 0           DAL         95         1    2016 2015-12-09   True           0
# 1           ATL         98         0    2016 2015-12-09  False           1
# 2           SAS        107         1    2018 2017-10-18  False           0
# 3           MIN         99         0    2018 2017-10-18   True           1
# 4           MEM         92         1    2021 2021-04-30  False           0
# ...         ...        ...       ...     ...        ...    ...         ...
# 17767       OKC         92         0    2019 2018-10-19   True           1
# 17768       ORL        108         1    2017 2016-12-14   True           0
# 17769       LAC        113         0    2017 2016-12-14  False           1
# 17770       MIA        106         1    2020 2020-09-19   True           0
# 17771       BOS        117         0    2020 2020-09-19  False           1
#
#        opp_code  day_code
# 0             6         2
# 1             0         2
# 2            26         2
# 3            17         2
# 4            14         4
# ...         ...       ...
# 17767        20         4
# 17768        21         2
# 17769        12         2
# 17770        15         5
# 17771         1         5
#
# [17772 rows x 152 columns]

# %% [markdown]
# The following code sets up a target to predict

# %%
games["target"] = (games["won"] == True).astype("int")

# %%
games
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  team_opp  \
# 0      240  39   81  0.481   6   20  0.300  14   18  0.778  ...       DAL
# 1      240  36  100  0.360   7   31  0.226  16   19  0.842  ...       ATL
# 2      240  37   85  0.435   8   19  0.421  17   23  0.739  ...       SAS
# 3      240  41   89  0.461   8   21  0.381  17   19  0.895  ...       MIN
# 4      240  27   86  0.314   6   26  0.231  15   20  0.750  ...       MEM
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 17767  240  35   81  0.432  11   26  0.423  27   36  0.750  ...       OKC
# 17768  240  37   74  0.500  13   25  0.520  26   37  0.703  ...       ORL
# 17769  240  42   89  0.472  14   33  0.424  10   20  0.500  ...       LAC
# 17770  240  41   85  0.482   9   26  0.346  26   30  0.867  ...       MIA
# 17771  240  33   85  0.388  12   44  0.273  28   34  0.824  ...       BOS
#
#        total_opp  home_opp  season       date    won  venue_code  opp_code  \
# 0             95         1    2016 2015-12-09   True           0         6
# 1             98         0    2016 2015-12-09  False           1         0
# 2            107         1    2018 2017-10-18  False           0        26
# 3             99         0    2018 2017-10-18   True           1        17
# 4             92         1    2021 2021-04-30  False           0        14
# ...          ...       ...     ...        ...    ...         ...       ...
# 17767         92         0    2019 2018-10-19   True           1        20
# 17768        108         1    2017 2016-12-14   True           0        21
# 17769        113         0    2017 2016-12-14  False           1        12
# 17770        106         1    2020 2020-09-19   True           0        15
# 17771        117         0    2020 2020-09-19  False           1         1
#
#        day_code  target
# 0             2       1
# 1             2       0
# 2             2       0
# 3             2       1
# 4             4       0
# ...         ...     ...
# 17767         4       1
# 17768         2       1
# 17769         2       0
# 17770         5       1
# 17771         5       0
#
# [17772 rows x 153 columns]

# %% [markdown]
# # Training our neural network model

# %% [markdown]
# Scaling data having vector X as [0], or standardise to have mean 0 and variance 1(ask about this)
# StandardScaler is used for standardisation

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Multi-layer Perceptron (MLP) is a supervised learning algorithm that learns a function
#  by training on a dataset, where
#  is the number of dimensions for input and
#  is the number of dimensions for output. Given a set of features
#  and a target
# , it can learn a non-linear function approximator for either classification or regression. It is different from logistic regression, in that between the input and the output layer, there can be one or more non-linear layers, called hidden layers. Figure 1 shows a one hidden layer MLP with scalar output.
# Reference: https://scikit-learn.org/stable/modules/neural_networks_supervised.html#tips-on-practical-use

# %% [markdown]
# This Class MLPClassifier implements a multi-layer perceptron (MLP) algorithm that trains using backpropagation(taking the error rate of a forward propagation and feeding this loss backwards through the neural network layer to fine-tune the weights, key to neural net training)
# Reference: https://builtin.com/machine-learning/backpropagation-neural-network

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %% [markdown]
# MLP trains on two arrays: array X of size (n_samples, n_features), which holds the training samples represented as floating point feature vectors; and array y of size (n_samples,), which holds the target values (class labels) for the training samples:

# %%
clf = MLPClassifier(random_state=1, max_iter=300)

# %%
predictors = ["venue_code","opp_code","day_code"]
X_train = games[games["date"]<'2020-10-11']#["predictors"]#.astype("int")
y_train = games[games["date"]<'2020-10-11']#["target"]#.astype("int")
X_test = games[games["date"]>'2020-10-11']#["predictors"]#.astype("int")
y_test = games[games["date"]>'2020-10-11']#["target"]#.astype("int")

# %%
 #X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=1)

# %%
clf.fit(X_train[predictors], y_train["target"])
#X_train[targets], y_train[targets]
# Out:
# MLPClassifier(max_iter=300, random_state=1)

# %%
preds = clf.predict(X_test[predictors])
#X_test[predictors], y_test[predictors]

# %% [markdown]
# # Performance metrics for our neural network model

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(X_test["target"], preds)

# %%
acc
# Out:
# 0.5402967121090617

# %%
combined = pd.DataFrame(dict(actual=X_test["target"], prediction=preds))

# %%
pd.crosstab(index= combined["actual"],columns=combined["prediction"])
# Out:
# prediction     0     1
# actual
# 0           1138  1356
# 1            937  1557

# %% [markdown]
# 470 times the model was correct, 320 times the model was wrong
# 401 times the model was correct, 389 times the model was wrong

# %%
from sklearn.metrics import precision_score

# %%
precision_score(X_test["target"], preds)
# Out:
# 0.5345005149330587

# %%
from sklearn.metrics import recall_score

recall_score(X_test["target"], preds)
# Out:
# 0.6242983159582999

# %%
from sklearn.metrics import f1_score

f1_score(X_test["target"], preds)
# Out:
# 0.575920103569447

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(X_test["target"], preds)
# Out:
# array([[1138, 1356],
#        [ 937, 1557]], dtype=int64)

# %% [markdown]
# # Improvement of our neural network model with rolling averages
#
# Improving the precison with rolling averages- by splitting the data set up in teams
# This groups the data set into team statistics

# %%
grouped_games = games.groupby("team")

# %%
group = grouped_games.get_group("GSW")

# %%
group
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  team_opp  \
# 18     240  46   97  0.474  19   42  0.452   9   15  0.600  ...       ORL
# 27     240  42   80  0.525  15   38  0.395  17   24  0.708  ...       PHI
# 77     240  43   91  0.473  12   21  0.571  11   13  0.846  ...       DET
# 112    240  33   95  0.347  16   48  0.333  17   24  0.708  ...       MIL
# 118    240  34   94  0.362  10   25  0.400  17   23  0.739  ...       DET
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 17688  240  38   78  0.487  12   28  0.429  20   24  0.833  ...       POR
# 17694  240  43   92  0.467  10   40  0.250  15   21  0.714  ...       ATL
# 17698  240  51   93  0.548  15   35  0.429  15   18  0.833  ...       LAC
# 17713  265  53  102  0.520  14   37  0.378  14   15  0.933  ...       HOU
# 17722  240  37   89  0.416  14   40  0.350  24   29  0.828  ...       PHO
#
#        total_opp  home_opp  season       date    won  venue_code  opp_code  \
# 18           124         1    2021 2021-02-19  False           0        21
# 27            96         0    2022 2021-11-24   True           1        22
# 77            95         0    2016 2015-11-09   True           1         8
# 112          118         1    2022 2022-01-13  False           0        16
# 118          113         1    2016 2016-01-16  False           0         8
# ...          ...       ...     ...        ...    ...         ...       ...
# 17688        125         1    2018 2018-03-09  False           0        24
# 17694        117         1    2021 2021-04-04  False           0         0
# 17698        105         1    2019 2019-04-18   True           0        12
# 17713        135         0    2019 2019-01-03  False           1        10
# 17722        104         1    2016 2016-02-10   True           0        23
#
#        day_code  target
# 18            4       0
# 27            2       1
# 77            0       1
# 112           3       0
# 118           5       0
# ...         ...     ...
# 17688         4       0
# 17694         6       0
# 17698         3       1
# 17713         3       0
# 17722         2       1
#
# [655 rows x 153 columns]

# %% [markdown]
# The games of GSW (Golden State Warriors)if the prediction is on the fourth game the model should look at the previous three games to help make better predictions. For example if the team is on a losing streak or a winning streak

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    #closed = ''left' only have the rolling averages of the previous weeks not the week we are trying to calculate for
    rolling_stats = group[cols].rolling(3,closed='left').mean()
    group[new_cols] = rolling_stats
    #removes all of the rows that have missing values 
    group = group.dropna(subset= new_cols)
    return group

# %% [markdown]
# Using the same roling averages as the ones used for Random Forest

# %%
#the 3 point feature was removed to complete an ablation test 
cols = ["fg","ft","ast","stl","blk","tov", "pts"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['fg_rolling',
#  'ft_rolling',
#  'ast_rolling',
#  'stl_rolling',
#  'blk_rolling',
#  'tov_rolling',
#  'pts_rolling']

# %% [markdown]
# These new columns are just for the LAL games

# %%
rolling_averages(group, cols, new_cols)
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  opp_code  \
# 1561   240  43   84  0.512  11   25  0.440  22   30  0.733  ...        14
# 8061   240  39   85  0.459  10   26  0.385  24   31  0.774  ...        12
# 13705  240  46   93  0.495  17   37  0.459  10   18  0.556  ...         7
# 7734   240  38   92  0.413   8   39  0.205  19   22  0.864  ...        25
# 77     240  43   91  0.473  12   21  0.571  11   13  0.846  ...         8
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 9063   240  39   86  0.453  15   37  0.405  14   20  0.700  ...         1
# 16380  240  36   78  0.462  15   40  0.375  13   15  0.867  ...         1
# 972    240  40   91  0.440  15   43  0.349  12   15  0.800  ...         1
# 11533  240  41   88  0.466   9   40  0.225  13   15  0.867  ...         1
# 7476   240  38   92  0.413  19   46  0.413   8    8  1.000  ...         1
#
#        day_code  target  fg_rolling  ft_rolling  ast_rolling  stl_rolling  \
# 1561          0       1   43.333333   20.666667    27.000000     9.000000
# 8061          2       1   44.000000   21.333333    28.000000     9.000000
# 13705         4       1   42.666667   23.666667    28.666667     8.000000
# 7734          5       1   42.666667   18.666667    33.333333     8.000000
# 77            0       1   41.000000   17.666667    31.666667     9.666667
# ...         ...     ...         ...         ...          ...          ...
# 9063          6       1   41.666667   14.666667    28.666667     6.333333
# 16380         2       0   41.000000   13.666667    28.333333     9.666667
# 972           4       1   38.000000   12.666667    23.666667    10.000000
# 11533         0       1   38.333333   13.000000    22.333333    10.666667
# 7476          3       1   39.000000   12.666667    21.666667     8.666667
#
#        blk_rolling  tov_rolling  pts_rolling
# 1561      5.000000    12.666667   119.000000
# 8061      7.000000    10.666667   121.666667
# 13705     7.333333    12.000000   121.666667
# 7734      8.000000    15.333333   116.666667
# 77        4.333333    16.666667   111.333333
# ...            ...          ...          ...
# 9063      4.333333    10.666667   112.333333
# 16380     3.666667    12.000000   111.666667
# 972       4.333333    14.000000   105.000000
# 11533     4.000000    14.666667   104.666667
# 7476      4.000000    12.666667   103.666667
#
# [652 rows x 160 columns]

# %% [markdown]
# After getting the original nba_games data Frame and grouped by teams which creates one data frame for each team in the data. Then the lambda function was applied to compute the rolling averages.

# %%
games_rolling = games.groupby("team").apply(lambda x:rolling_averages(x, cols, new_cols))

# %% [markdown]
# Rolling averages is applied to the entire data set

# %%
games_rolling
# Out:
#              mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  \
# team                                                             ...
# ATL  16278  240  37   88  0.420   7   29  0.241  13   14  0.929  ...
#      15680  240  37   90  0.411   7   21  0.333  17   22  0.773  ...
#      9779   240  37   76  0.487   8   22  0.364  19   24  0.792  ...
#      2860   240  41   77  0.532   9   21  0.429  30   35  0.857  ...
#      4159   240  43   92  0.467  13   33  0.394  15   15  1.000  ...
# ...         ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...
# WAS  12460  240  38   82  0.463   8   21  0.381  18   20  0.900  ...
#      15420  240  56  101  0.554  13   30  0.433   7   14  0.500  ...
#      9110   240  42   86  0.488  10   35  0.286   9   11  0.818  ...
#      14751  240  35   69  0.507   9   28  0.321  13   17  0.765  ...
#      1132   240  42   94  0.447   8   23  0.348  16   26  0.615  ...
#
#             opp_code  day_code  target  fg_rolling  ft_rolling  ast_rolling  \
# team
# ATL  16278         4         6       1   38.333333   15.666667    23.666667
#      15680        15         1       1   38.333333   16.000000    23.666667
#      9779          2         2       1   36.666667   15.666667    23.333333
#      2860         18         4       1   37.000000   16.333333    24.666667
#      4159         29         5       1   38.333333   22.000000    27.333333
# ...              ...       ...     ...         ...         ...          ...
# WAS  12460         1         6       0   44.666667   17.333333    31.000000
#      15420        17         1       1   44.666667   19.333333    29.666667
#      9110          0         2       0   47.666667   15.000000    30.666667
#      14751        19         4       0   45.333333   11.333333    28.333333
#      1132          4         6       0   44.333333    9.666667    28.333333
#
#             stl_rolling  blk_rolling  tov_rolling  pts_rolling
# team
# ATL  16278     9.666667     4.000000    15.000000   101.000000
#      15680     9.666667     4.666667    13.666667   101.000000
#      9779      9.333333     3.666667    13.666667    96.333333
#      2860     11.333333     5.666667    13.000000    97.666667
#      4159     11.666667     5.666667    14.333333   106.666667
# ...                 ...          ...          ...          ...
# WAS  12460     6.000000     6.333333    11.333333   118.666667
#      15420     5.333333     4.666667    10.666667   121.333333
#      9110      5.000000     3.333333    10.333333   123.000000
#      14751     4.000000     3.333333    12.000000   112.333333
#      1132      4.333333     4.333333    15.333333   109.000000
#
# [17682 rows x 160 columns]

# %% [markdown]
# Dropping the team name as a seperate level in the pandas index. for a multi level index you would need to use two values to access each row which was not needed

# %%
games_rolling = games_rolling.droplevel('team')

# %%
games_rolling
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  opp_code  \
# 16278  240  37   88  0.420   7   29  0.241  13   14  0.929  ...         4
# 15680  240  37   90  0.411   7   21  0.333  17   22  0.773  ...        15
# 9779   240  37   76  0.487   8   22  0.364  19   24  0.792  ...         2
# 2860   240  41   77  0.532   9   21  0.429  30   35  0.857  ...        18
# 4159   240  43   92  0.467  13   33  0.394  15   15  1.000  ...        29
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 12460  240  38   82  0.463   8   21  0.381  18   20  0.900  ...         1
# 15420  240  56  101  0.554  13   30  0.433   7   14  0.500  ...        17
# 9110   240  42   86  0.488  10   35  0.286   9   11  0.818  ...         0
# 14751  240  35   69  0.507   9   28  0.321  13   17  0.765  ...        19
# 1132   240  42   94  0.447   8   23  0.348  16   26  0.615  ...         4
#
#        day_code  target  fg_rolling  ft_rolling  ast_rolling  stl_rolling  \
# 16278         6       1   38.333333   15.666667    23.666667     9.666667
# 15680         1       1   38.333333   16.000000    23.666667     9.666667
# 9779          2       1   36.666667   15.666667    23.333333     9.333333
# 2860          4       1   37.000000   16.333333    24.666667    11.333333
# 4159          5       1   38.333333   22.000000    27.333333    11.666667
# ...         ...     ...         ...         ...          ...          ...
# 12460         6       0   44.666667   17.333333    31.000000     6.000000
# 15420         1       1   44.666667   19.333333    29.666667     5.333333
# 9110          2       0   47.666667   15.000000    30.666667     5.000000
# 14751         4       0   45.333333   11.333333    28.333333     4.000000
# 1132          6       0   44.333333    9.666667    28.333333     4.333333
#
#        blk_rolling  tov_rolling  pts_rolling
# 16278     4.000000    15.000000   101.000000
# 15680     4.666667    13.666667   101.000000
# 9779      3.666667    13.666667    96.333333
# 2860      5.666667    13.000000    97.666667
# 4159      5.666667    14.333333   106.666667
# ...            ...          ...          ...
# 12460     6.333333    11.333333   118.666667
# 15420     4.666667    10.666667   121.333333
# 9110      3.333333    10.333333   123.000000
# 14751     3.333333    12.000000   112.333333
# 1132      4.333333    15.333333   109.000000
#
# [17682 rows x 160 columns]

# %%
games_rolling.index = range(games_rolling.shape[0])

# %%
games_rolling
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  opp_code  \
# 0      240  37   88  0.420   7   29  0.241  13   14  0.929  ...         4
# 1      240  37   90  0.411   7   21  0.333  17   22  0.773  ...        15
# 2      240  37   76  0.487   8   22  0.364  19   24  0.792  ...         2
# 3      240  41   77  0.532   9   21  0.429  30   35  0.857  ...        18
# 4      240  43   92  0.467  13   33  0.394  15   15  1.000  ...        29
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 17677  240  38   82  0.463   8   21  0.381  18   20  0.900  ...         1
# 17678  240  56  101  0.554  13   30  0.433   7   14  0.500  ...        17
# 17679  240  42   86  0.488  10   35  0.286   9   11  0.818  ...         0
# 17680  240  35   69  0.507   9   28  0.321  13   17  0.765  ...        19
# 17681  240  42   94  0.447   8   23  0.348  16   26  0.615  ...         4
#
#        day_code  target  fg_rolling  ft_rolling  ast_rolling  stl_rolling  \
# 0             6       1   38.333333   15.666667    23.666667     9.666667
# 1             1       1   38.333333   16.000000    23.666667     9.666667
# 2             2       1   36.666667   15.666667    23.333333     9.333333
# 3             4       1   37.000000   16.333333    24.666667    11.333333
# 4             5       1   38.333333   22.000000    27.333333    11.666667
# ...         ...     ...         ...         ...          ...          ...
# 17677         6       0   44.666667   17.333333    31.000000     6.000000
# 17678         1       1   44.666667   19.333333    29.666667     5.333333
# 17679         2       0   47.666667   15.000000    30.666667     5.000000
# 17680         4       0   45.333333   11.333333    28.333333     4.000000
# 17681         6       0   44.333333    9.666667    28.333333     4.333333
#
#        blk_rolling  tov_rolling  pts_rolling
# 0         4.000000    15.000000   101.000000
# 1         4.666667    13.666667   101.000000
# 2         3.666667    13.666667    96.333333
# 3         5.666667    13.000000    97.666667
# 4         5.666667    14.333333   106.666667
# ...            ...          ...          ...
# 17677     6.333333    11.333333   118.666667
# 17678     4.666667    10.666667   121.333333
# 17679     3.333333    10.333333   123.000000
# 17680     3.333333    12.000000   112.333333
# 17681     4.333333    15.333333   109.000000
#
# [17682 rows x 160 columns]

# %%
def make_predictions(data,predictors):
    X_train = data[data["date"]<'2022-01-01']
    y_test = data[data["date"]>'2022-01-01']
    clf.fit(X_train[predictors], X_train["target"])
    preds = clf.predict(y_test[predictors])
    combined = pd.DataFrame(dict(actual=y_test["target"], predicted=preds), index=y_test.index)
    precision = precision_score(y_test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(games_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5528255528255528

# %%
combined
# Out:
#        actual  predicted
# 533         0          0
# 534         1          0
# 535         0          0
# 536         0          0
# 537         0          1
# ...       ...        ...
# 17677       0          0
# 17678       1          0
# 17679       0          0
# 17680       0          1
# 17681       0          0
#
# [1580 rows x 2 columns]

# %%
#merges rows based on index
combined = combined.merge(games_rolling[["date", "team", "team_opp", "won"]], left_index=True, right_index=True)

# %%
#information about the team that played their opponent and the result
combined
# Out:
#        actual  predicted       date team team_opp    won
# 533         0          0 2022-01-03  ATL      POR  False
# 534         1          0 2022-01-05  ATL      SAC   True
# 535         0          0 2022-01-07  ATL      LAL  False
# 536         0          0 2022-01-09  ATL      LAC  False
# 537         0          1 2022-01-12  ATL      MIA  False
# ...       ...        ...        ...  ...      ...    ...
# 17677       0          0 2022-04-03  WAS      BOS  False
# 17678       1          0 2022-04-05  WAS      MIN   True
# 17679       0          0 2022-04-06  WAS      ATL  False
# 17680       0          1 2022-04-08  WAS      NYK  False
# 17681       0          0 2022-04-10  WAS      CHO  False
#
# [1580 rows x 6 columns]

# %% [markdown]
# Combining home and away predictions

# %%
#to make sure the names of the home and away team are the same 
#the Dataset already has the same names for home and away teams
#for future reference if names need to be normalised
class MissingDict(dict):
    __missing__ = lambda self, key: key
    
map_values = {
    
    "Golden State Warriors": "GSW",
    "Lakers": "LAL",
    "Boston Celtics": "BOS"
    
}
mapping = MissingDict(**map_values)

# %%
mapping["Golden State Warriors"]
# Out:
# 'GSW'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#        actual  predicted       date team team_opp    won new_team
# 533         0          0 2022-01-03  ATL      POR  False      ATL
# 534         1          0 2022-01-05  ATL      SAC   True      ATL
# 535         0          0 2022-01-07  ATL      LAL  False      ATL
# 536         0          0 2022-01-09  ATL      LAC  False      ATL
# 537         0          1 2022-01-12  ATL      MIA  False      ATL
# ...       ...        ...        ...  ...      ...    ...      ...
# 17677       0          0 2022-04-03  WAS      BOS  False      WAS
# 17678       1          0 2022-04-05  WAS      MIN   True      WAS
# 17679       0          0 2022-04-06  WAS      ATL  False      WAS
# 17680       0          1 2022-04-08  WAS      NYK  False      WAS
# 17681       0          0 2022-04-10  WAS      CHO  False      WAS
#
# [1580 rows x 7 columns]

# %% [markdown]
# This makes sure that the predictions are the same on both sides

# %%
merged = combined.merge(combined, left_on=["date","new_team"], right_on=["date","team_opp"])

# %%
merged
# Out:
#       actual_x  predicted_x       date team_x team_opp_x  won_x new_team_x  \
# 0            0            0 2022-01-03    ATL        POR  False        ATL
# 1            1            0 2022-01-05    ATL        SAC   True        ATL
# 2            0            0 2022-01-07    ATL        LAL  False        ATL
# 3            0            0 2022-01-09    ATL        LAC  False        ATL
# 4            0            1 2022-01-12    ATL        MIA  False        ATL
# ...        ...          ...        ...    ...        ...    ...        ...
# 1575         0            0 2022-04-03    WAS        BOS  False        WAS
# 1576         1            0 2022-04-05    WAS        MIN   True        WAS
# 1577         0            0 2022-04-06    WAS        ATL  False        WAS
# 1578         0            1 2022-04-08    WAS        NYK  False        WAS
# 1579         0            0 2022-04-10    WAS        CHO  False        WAS
#
#       actual_y  predicted_y team_y team_opp_y  won_y new_team_y
# 0            1            1    POR        ATL   True        POR
# 1            0            0    SAC        ATL  False        SAC
# 2            1            1    LAL        ATL   True        LAL
# 3            1            1    LAC        ATL   True        LAC
# 4            1            0    MIA        ATL   True        MIA
# ...        ...          ...    ...        ...    ...        ...
# 1575         1            1    BOS        WAS   True        BOS
# 1576         0            1    MIN        WAS  False        MIN
# 1577         1            1    ATL        WAS   True        ATL
# 1578         1            0    NYK        WAS   True        NYK
# 1579         1            1    CHO        WAS   True        CHO
#
# [1580 rows x 13 columns]

# %%
#def show_missing(games):
 #   """Return a Pandas dataframe describing the contents of a source dataframe including missing values."""
    
  #  variables = []
   # dtypes = []
    #count = []
#    unique = []
#    missing = []
 #   pc_missing = []
    
  #  for item in games.columns:
   #     variables.append(item)
    #    dtypes.append(games[item].dtype)
     #   count.append(len(games[item]))
      #  unique.append(len(games[item].unique()))
       # missing.append(games[item].isna().sum())
        #pc_missing.append(round((games[item].isna().sum() / len(games[item])) * 100, 2))

#    output = pd.DataFrame({
 #       'variable': variables, 
  #      'dtype': dtypes,
   #     'count': count,
    #    'unique': unique,
     #   'missing': missing, 
      #  'pc_missing': pc_missing
    #})    
        
    #return output

# %%
#show_missing(games)

# %%
nulls = pd.isnull(games)
nulls = nulls.sum()
nulls = nulls[nulls > 0]
nulls
# Out:
# +/-             17772
# mp_max          17772
# mp_max.1        17772
# +/-_opp         17772
# mp_max_opp      17772
# mp_max_opp.1    17772
# dtype: int64

# %%
merged
# Out:
#       actual_x  predicted_x       date team_x team_opp_x  won_x new_team_x  \
# 0            0            0 2022-01-03    ATL        POR  False        ATL
# 1            1            0 2022-01-05    ATL        SAC   True        ATL
# 2            0            0 2022-01-07    ATL        LAL  False        ATL
# 3            0            0 2022-01-09    ATL        LAC  False        ATL
# 4            0            1 2022-01-12    ATL        MIA  False        ATL
# ...        ...          ...        ...    ...        ...    ...        ...
# 1575         0            0 2022-04-03    WAS        BOS  False        WAS
# 1576         1            0 2022-04-05    WAS        MIN   True        WAS
# 1577         0            0 2022-04-06    WAS        ATL  False        WAS
# 1578         0            1 2022-04-08    WAS        NYK  False        WAS
# 1579         0            0 2022-04-10    WAS        CHO  False        WAS
#
#       actual_y  predicted_y team_y team_opp_y  won_y new_team_y
# 0            1            1    POR        ATL   True        POR
# 1            0            0    SAC        ATL  False        SAC
# 2            1            1    LAL        ATL   True        LAL
# 3            1            1    LAC        ATL   True        LAC
# 4            1            0    MIA        ATL   True        MIA
# ...        ...          ...    ...        ...    ...        ...
# 1575         1            1    BOS        WAS   True        BOS
# 1576         0            1    MIN        WAS  False        MIN
# 1577         1            1    ATL        WAS   True        ATL
# 1578         1            0    NYK        WAS   True        NYK
# 1579         1            1    CHO        WAS   True        CHO
#
# [1580 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prediction_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6332\15596472.py in <module>
# ----> 1 merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'prediction_x'

# %% [markdown]
# The accuracy is 76.5% from merging both sides of the match together however manyrows were unable to be recovered to get an accuracy on all of the data frames rows.
# Using more seasons could improve accuracy
# Using more columns in the data frame can improve accuracy
# Look at both current team and opponent team records for the season

# %%
combined, accuracy = make_predictions(games_rolling, predictors + new_cols)

# %%
def make_predictions(data,predictors):
    X_train = data[data["date"]<'2022-01-01']
    y_test = data[data["date"]>'2022-01-01']
    clf.fit(X_train[predictors], X_train["target"])
    preds = clf.predict(y_test[predictors])
    combined = pd.DataFrame(dict(actual=y_test["target"], predicted=preds), index=y_test.index)
    accuracy = accuracy_score(y_test["target"], preds)
    return combined, accuracy

# %%
merged, accuracy = make_predictions(games_rolling, predictors + new_cols)

# %%
accuracy

# %% [markdown]
# #### 55% accuracy with rolling averages
